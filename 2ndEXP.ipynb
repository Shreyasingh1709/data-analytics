# %%
pip install matplotlib
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: seaborn in c:\users\shrey\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           NaN          0.2     Iris-setosa
# 2             4.7          3.2           NaN          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          NaN           NaN          NaN     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randint(1,100,(2,5))
plt.scatter(data) 
plt.title("Scatter plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 import numpy as np
#       3 data = np.random.randint(1,100,(2,5))
# ----> 4 plt.scatter(data)
#       5 plt.title("Scatter plot")
#       6 plt.show()
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(1,100,(2,5))
print("X:")
print(x)
y = np.random.randint(1,100,(2,5))
print("Y:")
print(y)
#shape of x and y should be same
plt.scatter(x,y) 
plt.title("Scatter plot")
plt.ylabel("Y")
plt.xlabel("X")
plt.show()
# Out:
# X:
# [[90 11 90 52 74]
#  [35 51 83 71 53]]
# Y:
# [[99 64 81 14  3]
#  [26  3 47 60 45]]

# %%
import matplotlib.pyplot as plt
import numpy as np
#'#' is not a valid marker style in Matplotlib.
#Valid marker options include 'o', 's', '^', '*', etc.
#plt.scatter(x, y) requires 1D arrays
#x and y are 2D arrays of shape (2,5), but plt.scatter() expects 1D arrays.
#You need to flatten them using .flatten().
x = np.random.randint(1,100,(1,5))
print("X:")
print(x)
y = np.random.randint(1,100,(1,5))
print("Y:")
print(y)
#shape of x and y should be same
plt.scatter(x,y,color = 'brown',marker = '*') 
plt.title("Scatter plot")
plt.show()
# Out:
# X:
# [[79 71 26 36 52]]
# Y:
# [[51 69 86 81 53]]

# %%
import matplotlib.pyplot as plt
import numpy as np
#generating random floating-point numbers is np.random.uniform().
x = np.random.randfloat(1,100,(2,5))
print("X:")
print(x)
#np.random.randn() does not accept a (low, high, size) format.
#If you want random values in a range, use np.random.uniform(low, high, size) instead.
y = np.random.randn(1,100,(2,5))
print("Y:")
print(y)
#shape of x and y should be same
plt.scatter(x,y) 
plt.title("Scatter plot")
plt.ylabel("Y")
plt.xlabel("X")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       2 import numpy as np
#       3 #generating random floating-point numbers is np.random.uniform().
# ----> 4 x = np.random.randfloat(1,100,(2,5))
#       5 print("X:")
#       6 print(x)
#
# AttributeError: module 'numpy.random' has no attribute 'randfloat'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
ax=sns.heatmap(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       4 x = np.random.randint(1,100,(50,20))
#       5 y = np.random.randint(1,100,(50,20))
# ----> 6 ax=sns.heatmap(x,y)
#
# TypeError: heatmap() takes 1 positional argument but 2 were given

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data = np.random.randint(1,100,(50,20))
ax=sns.heatmap(data)
plt.title("Heatmap")
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
ax = sns.countplot(data)
plt.title("Count plot")
# Out:
# Text(0.5, 1.0, 'Count plot')

# %%
ax= sns.histplot(data)
plt.title("Hist plot")
# Out:
# Text(0.5, 1.0, 'Hist plot')

# %%
x = np.random.randint(0,10,1000)
y = np.random.randint(0,10,1000)
plt.hist2d(x,y)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
plt.pie(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plt.pie(data)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
plt.pie(x,y)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17732\4148149679.py:3: MatplotlibDeprecationWarning: Passing the explode parameter of pie() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.pie(x,y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 x = np.random.randint(1,100,(50,20))
#       2 y = np.random.randint(1,100,(50,20))
# ----> 3 plt.pie(x,y)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
# ...

# %%
#plt.pie() requires a 1D array
x = np.random.randint(1,100,(50,20))
plt.pie(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 x = np.random.randint(1,100,(50,20))
# ----> 2 plt.pie(x)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x = np.random.randint(1,5)
plt.pie(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 x = np.random.randint(1,5)
# ----> 2 plt.pie(x)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x = np.random.randint(1,10,5)
plt.pie(x)
plt.title("Bar graph")
# Out:
# Text(0.5, 1.0, 'Bar graph')

# %%
plt.pie(x,autopct = '%1.1f%%')
plt.title("Bar graph with %")
#'%1.1f%%' → 1 decimal place (e.g., 25.3%)
#'%1.0f%%' → No decimal places (e.g., 25%)
#'%1.2f%%' → 2 decimal places (e.g., 25.34%)
# Out:
# Text(0.5, 1.0, 'Bar graph with %')

# %%
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
sns.barplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 x = np.random.randint(1,100,(50,20))
#       2 y = np.random.randint(1,100,(50,20))
# ----> 3 sns.barplot(x,y)
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
ax = sns.barplot(data)
plt.title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %%
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 x = np.random.randint(1,100,(50,20))
#       2 y = np.random.randint(1,100,(50,20))
# ----> 3 plt.bar(x,y)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# ...

# %%
x = np.random.randint(1,10,10)
print("X:",x)
y = np.random.randint(1,10,10)
print("Y:",y)
plt.bar(x,y)
plt.title("Bar graph")
plt.ylabel("Y")
plt.xlabel("X")
# Out:
# X: [9 4 3 6 6 8 9 1 5 3]
# Y: [2 5 2 2 4 7 6 4 8 7]
# Text(0.5, 0, 'X')

# %%
#it expects a 1D or 2D array where each column represents a different dataset.
#Instead, pass only x or y as a list of 1D arrays.
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
plt.violinplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 3
#       1 x = np.random.randint(1,100,(50,20))
#       2 y = np.random.randint(1,100,(50,20))
# ----> 3 plt.violinplot(x,y)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x = np.random.randint(1,100,(50,20))
plt.violinplot(x)
plt.title("Voilin plot")
# Out:
# Text(0.5, 1.0, 'Voilin plot')

# %%
x = np.random.randint(1,100,(50,20))
y = np.random.randint(1,100,(50,20))
plt.stackplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 3
#       1 x = np.random.randint(1,100,(50,20))
#       2 y = np.random.randint(1,100,(50,20))
# ----> 3 plt.stackplot(x,y)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:4052, in stackplot(x, labels, colors, hatch, baseline, data, *args, **kwargs)
#    4048 @_copy_docstring_and_deprecators(Axes.stackplot)
#    4049 def stackplot(
#    4050     x, *args, labels=(), colors=None, hatch=None, baseline="zero", data=None, **kwargs
#    4051 ):
# -> 4052     return gca().stackplot(
#    4053         x,
#    4054         *args,
#    4055         labels=labels,
#    4056         colors=colors,
#    4057         hatch=hatch,
#    4058         baseline=baseline,
#    4059         **({"data": data} if data is not None else {}),
#    4060         **kwargs,
# ...

# %%
x = np.random.randint(1,10,100)
y = np.random.randint(1,10,100)
plt.violinplot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 3
#       1 x = np.random.randint(1,10,100)
#       2 y = np.random.randint(1,10,100)
# ----> 3 plt.violinplot(x,y)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
x = np.random.randint(1,10,100)
plt.stackplot(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 x = np.random.randint(1,10,100)
# ----> 2 plt.stackplot(x)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:4052, in stackplot(x, labels, colors, hatch, baseline, data, *args, **kwargs)
#    4048 @_copy_docstring_and_deprecators(Axes.stackplot)
#    4049 def stackplot(
#    4050     x, *args, labels=(), colors=None, hatch=None, baseline="zero", data=None, **kwargs
#    4051 ):
# -> 4052     return gca().stackplot(
#    4053         x,
#    4054         *args,
#    4055         labels=labels,
#    4056         colors=colors,
#    4057         hatch=hatch,
#    4058         baseline=baseline,
#    4059         **({"data": data} if data is not None else {}),
#    4060         **kwargs,
#    4061     )
#
# ...

# %%
x = np.random.randint(1,10,10)
y = np.random.randint(1,10,10)
plt.stackplot(x,y)
plt.title("Stack plot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x = np.random.randint(1,10,10)
#       2 y = np.random.randint(1,10,10)
#       3 plt.stackplot(x,y)
#
# NameError: name 'np' is not defined

# %%
x = np.random.randint(1,10,100)
plt.quiver(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 x = np.random.randint(1,10,100)
# ----> 2 plt.quiver(x)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3903, in quiver(data, *args, **kwargs)
#    3901 @_copy_docstring_and_deprecators(Axes.quiver)
#    3902 def quiver(*args, data=None, **kwargs) -> Quiver:
# -> 3903     __ret = gca().quiver(
#    3904         *args, **({"data": data} if data is not None else {}), **kwargs
#    3905     )
#    3906     sci(__ret)
#    3907     return __ret
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# ...

# %%
x = np.random.randint(1,10,100)
y = np.random.randint(1,10,100)
z = np.random.randint(1,10,100)
plt.quiver(x,y,z)
plt.title("Quiver")
# Out:
# Text(0.5, 1.0, 'Quiver')

# %%
x = np.random.randint(1,10,100)
y = np.random.randint(1,10,100)
z = np.random.randint(1,10,100)
sns.swarmplot(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 y = np.random.randint(1,10,100)
#       3 z = np.random.randint(1,10,100)
# ----> 4 sns.swarmplot(x,y,z)
#
# TypeError: swarmplot() takes from 0 to 1 positional arguments but 3 were given

# %%
x = np.random.randint(1,10,100)
sns.swarmplot(x)
plt.title("Swarm plot")
# Out:
# Text(0.5, 1.0, 'Swarm plot')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.plot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas as pd
#       3 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 4 plt.plot(df)
#       5 plt.show()
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.plot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")

# %%
plt.plot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.plot(df["sepal length"],df["sepal width"])
plt.xlabel("Seapl length")
plt.ylabel("Sepal width")
plt.title("Plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.scatter(df["sepal length"],df["sepal width"])
plt.xlabel("Seapl length")
plt.ylabel("Sepal width")
plt.title("Scatter plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.scatter(df["sepal length"],df["sepal width"],color = 'red',marker = '*')
plt.xlabel("Seapl length")
plt.ylabel("Sepal width")
plt.title("Scatter plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
sns.heatmap(df["sepal length"],df["sepal width"])
plt.xlabel("Seapl length")
plt.ylabel("Sepal width")
plt.title("Heat map")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       3 import pandas as pd
#       4 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 5 sns.heatmap(df["sepal length"],df["sepal width"])
#       6 plt.xlabel("Seapl length")
#       7 plt.ylabel("Sepal width")
#
# TypeError: heatmap() takes 1 positional argument but 2 were given

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
sns.heatmap(df["sepal length"])
plt.xlabel("Seapl length")
plt.title("Heat map")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 5
#       3 import pandas as pd
#       4 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 5 sns.heatmap(df["sepal length"])
#       6 plt.xlabel("Seapl length")
#       7 plt.title("Heat map")
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
sns.heatmap(df[['sepal length']])
plt.title("Heat map")
# Out:
# Text(0.5, 1.0, 'Heat map')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
sns.countplot(df["sepal length"])
plt.xlabel("Seapl length")
plt.title("Count plot")
# Out:
# Text(0.5, 1.0, 'Count plot')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
sns.histplot(df["sepal length"],bins = 30)
plt.xlabel("Seapl length")
plt.title("Hist plot")
# Out:
# Text(0.5, 1.0, 'Hist plot')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.hist2d(df["sepal length"],df['sepal width'])
plt.xlabel("Seapl length")
plt.ylabel("Sepal width")
plt.title("Histogram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 5
#       3 import pandas as pd
#       4 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 5 plt.hist2d(df["sepal length"],df['sepal width'])
#       6 plt.xlabel("Seapl length")
#       7 plt.ylabel("Sepal width")
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.hist2d(df["sepal length"],df['sepal width'])
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.title("Histogram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 5 plt.hist2d(df["sepal length"],df['sepal width'])
#       6 plt.xlabel("Sepal length")
#       7 plt.ylabel("Sepal width")
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
plt.hist2d(df["sepal length"],df['sepal width'],bins=30)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.title("Histogram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 5
#       3 import pandas as pd
#       4 df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
# ----> 5 plt.hist2d(df["sepal length"],df['sepal width'],bins=30)
#       6 plt.xlabel("Sepal length")
#       7 plt.ylabel("Sepal width")
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:/Users/shrey/Downloads/iris/iris.data.csv")
df= df.dropna()
plt.hist2d(df["sepal length"],df['sepal width'])
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
plt.pie(df["sepal length"])
plt.title("Pie graph")
# Out:
# Text(0.5, 1.0, 'Pie graph')

# %%
ax = sns.barplot(df['sepal length'])
plt.title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %%
plt.bar(df['sepal length'],df['sepal width'])
plt.title("Bar graph")
plt.ylabel("Sepal width")
plt.xlabel("Sepal length")
# Out:
# Text(0.5, 0, 'Sepal length')

# %%
plt.violinplot(df['sepal length'])
plt.title("Voilin plot")
# Out:
# Text(0.5, 1.0, 'Voilin plot')

# %%
plt.stackplot(df['sepal length'],df['sepal width'])
plt.title("Stack plot")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
plt.quiver(df['sepal length'],df['sepal width'])
plt.title("Quiver")
plt.xlabel("Sepal length")
plt.ylabel("Seapl width")
# Out:
# Text(0, 0.5, 'Seapl width')

# %%
sns.swarmplot(df['sepal length'])
plt.title("Swarm plot")
# Out:
# Text(0.5, 1.0, 'Swarm plot')

# %%
import math
math.floor(28.6)
# Out:
# 28

# %%
ce=math.ceil(28.6)
ce
# Out:
# 29

# %%
math.factorial(9)
# Out:
# 362880

# %%
math.pow(2,4)
# Out:
# 16.0

# %%
math.pwr(2,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 math.pwr(2,4)
#
# AttributeError: module 'math' has no attribute 'pwr'

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
math.fabs(-1.567)
# Out:
# 1.567

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(90)
# Out:
# -0.4480736161291701

# %%
math.tan(90)
# Out:
# -1.995200412208242

# %%
math.log10(4)
# Out:
# 0.6020599913279624

# %%
import statistics as st
st.mean([3,6,7,2,9,4])
# Out:
# 5.166666666666667

# %%
st.harmonic_mean([3,6,7,2,9,4])
# Out:
# 3.9894459102902378

# %%
st.median([3,6,7,2,9,4])
# Out:
# 5.0

# %%
st.mode([3,6,7,2,9,4])
# Out:
# 3

# %%
st.average([3,6,7,2,9,4])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 st.average([3,6,7,2,9,4])
#
# AttributeError: module 'statistics' has no attribute 'average'

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/41.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/41.0 MB 10.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.2/41.0 MB 8.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.2/41.0 MB 7.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.0/41.0 MB 6.7 MB/s eta 0:00:06
#    ------ --------------------------------- 6.6/41.0 MB 5.9 MB/s eta 0:00:06
#    ------ --------------------------------- 7.1/41.0 MB 5.4 MB/s eta 0:00:07
#    ------- -------------------------------- 7.9/41.0 MB 5.0 MB/s eta 0:00:07
#    -------- ------------------------------- 8.7/41.0 MB 4.8 MB/s eta 0:00:07
#    --------- ------------------------------ 9.4/41.0 MB 4.7 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.5/41.0 MB 4.7 MB/s eta 0:00:07
# ...

# %%
from scipy import stats as st
st.describe(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 from scipy import stats as st
# ----> 2 st.describe(df)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:1521, in describe(a, axis, ddof, bias, nan_policy)
#    1519 n = a.shape[axis]
#    1520 mm = (xp.min(a, axis=axis), xp.max(a, axis=axis))
# -> 1521 m = xp.mean(a, axis=axis)
#    1522 v = _var(a, axis=axis, ddof=ddof, xp=xp)
#    1523 sk = skew(a, axis, bias=bias)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# ...

# %%
from scipy import stats as st
desc = st.describe(df['sepal length'])
summary_df = pd.DataFrame({
    "Statistic": ["Count", "Mean", "Std Dev", "Min", "Max"],
    "Value": [desc.nobs, desc.mean, desc.variance**0.5, desc.minmax[0], desc.minmax[1]]
})

# Display the table
print(summary_df)
# Out:
#   Statistic       Value
# 0     Count  150.000000
# 1      Mean    5.843333
# 2   Std Dev    0.828066
# 3       Min    4.300000
# 4       Max    7.900000

# %%
st.cumfreq(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 st.cumfreq(df)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py:2381, in cumfreq(a, numbins, defaultreallimits, weights)
#    2309 def cumfreq(a, numbins=10, defaultreallimits=None, weights=None):
#    2310     """Return a cumulative frequency histogram, using the histogram function.
#    2311
#    2312     A cumulative histogram is a mapping that counts the cumulative number of
#    (...)
#    2379
#    2380     """
# -> 2381     h, l, b, e = _histogram(a, numbins, defaultreallimits, weights=weights)
#    2382     cumhist = np.cumsum(h * 1, axis=0)
#    2383     return CumfreqResult(cumhist, l, b, e)
#
# ...

# %%
st.cumfreq(df['sepal length'])
# Out:
# CumfreqResult(cumcount=array([  4.,  16.,  45.,  65.,  89., 115., 133., 142., 145., 150.]), lowerlimit=np.float64(4.1), binsize=np.float64(0.40000000000000036), extrapoints=0)

# %%
st.gmean(df['sepal length'])
# Out:
# np.float64(5.785720390427728)

# %%
st.hmean(df['sepal length'])
# Out:
# np.float64(5.728905057850834)

# %%
st.iqr(df['sepal length'])
# Out:
# np.float64(1.3000000000000007)

# %%
st.zscore(df['sepal length'])
# Out:
# array([-0.90068117, -1.14301691, -1.38535265, -1.50652052, -1.02184904,
#        -0.53717756, -1.50652052, -1.02184904, -1.74885626, -1.14301691,
#        -0.53717756, -1.26418478, -1.26418478, -1.87002413, -0.05250608,
#        -0.17367395, -0.53717756, -0.90068117, -0.17367395, -0.90068117,
#        -0.53717756, -0.90068117, -1.50652052, -0.90068117, -1.26418478,
#        -1.02184904, -1.02184904, -0.7795133 , -0.7795133 , -1.38535265,
#        -1.26418478, -0.53717756, -0.7795133 , -0.41600969, -1.14301691,
#        -1.02184904, -0.41600969, -1.14301691, -1.74885626, -0.90068117,
#        -1.02184904, -1.62768839, -1.74885626, -1.02184904, -0.90068117,
#        -1.26418478, -0.90068117, -1.50652052, -0.65834543, -1.02184904,
#         1.40150837,  0.67450115,  1.2803405 , -0.41600969,  0.79566902,
#        -0.17367395,  0.55333328, -1.14301691,  0.91683689, -0.7795133 ,
#        -1.02184904,  0.06866179,  0.18982966,  0.31099753, -0.29484182,
# ...

# %%
st.skew()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:509, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(_no_deco, *args, **kwds)
#     508 try:  # if something is missing
# --> 509     samples = [np.atleast_1d(kwds.pop(param))
#     510                for param in (params[:n_samp] + kwd_samp)]
#     511 except KeyError:  # let the function raise the right error
#     512     # might need to revisit this if required arg is not a "sample"
#
# KeyError: 'a'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 st.skew()
#
# ...

# %%
st.skew(df['sepal length'])
# Out:
# np.float64(0.3117530585022963)

# %%
st.kurtosis(df['sepal length'])
# Out:
# np.float64(-0.5735679489249765)

# %%
st.normaltest(df['sepal length'])
# Out:
# NormaltestResult(statistic=np.float64(4.113992699313099), pvalue=np.float64(0.127837372570807))

# %%
st.pearsonr(df['sepal length'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 st.pearsonr(df['sepal length'])
#
# TypeError: pearsonr() missing 1 required positional argument: 'y'

# %%
st.pearsonr(df['sepal length'],df['sepal width'])
# Out:
# PearsonRResult(statistic=np.float64(-0.08681340075978503), pvalue=np.float64(0.3008388275307354))

# %%
st.spearmanr(df['sepal length'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3656\219725499.py in ?()
# ----> 1 st.spearmanr(df['sepal length'])
#
# c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_stats_py.py in ?(a, b, axis, nan_policy, alternative)
#    5233         raise ValueError("spearmanr only handles 1-D or 2-D arrays")
#    5234
#    5235     if b is None:
#    5236         if a.ndim < 2:
# -> 5237             raise ValueError("`spearmanr` needs at least 2 "
#    5238                              "variables to compare")
#    5239     else:
#    5240         # Concatenate a and b, so that we now only have to handle the case
#
# ValueError: `spearmanr` needs at least 2 variables to compare

# %%
st.spearmanr(df['sepal length'],df['sepal width'])
# Out:
# SignificanceResult(statistic=np.float64(-0.12347197844738196), pvalue=np.float64(0.14037438579301373))

# %%
st.correlation(df['sepal length'],df['sepal width'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 st.correlation(df['sepal length'],df['sepal width'])
#
# AttributeError: module 'scipy.stats' has no attribute 'correlation'

# %%
correlation_matrix = df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 correlation_matrix = df.corr()
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
correlation_matrix = df.corr(df['sepal length'],df['sepal width'],df['petal length'],df['petal width'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 correlation_matrix = df.corr(df['sepal length'],df['sepal width'],df['petal length'],df['petal width'])
#
# TypeError: DataFrame.corr() takes from 1 to 4 positional arguments but 5 were given

# %%
correlation_matrix = df['sepal length','sepal width','petal length','petal width'].corr()
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\shrey\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sepal length', 'sepal width', 'petal length', 'petal width')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
correlation_matrix = df[['sepal length','sepal width','petal length','petal width']].corr()
print(correlation_matrix)
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.088995      0.864529     0.815076
# sepal width      -0.088995     1.000000     -0.410652    -0.340626
# petal length      0.864529    -0.410652      1.000000     0.960043
# petal width       0.815076    -0.340626      0.960043     1.000000

# %%
import seaborn as sns
sns.boxplot(x='sepal length',data = df)
# Out:
# <Axes: xlabel='sepal length'>

# %%
import matplotlib as plt
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>
